# %% [markdown]
# <a href="https://colab.research.google.com/github/amitadhainje/ImageRecognition/blob/main/Face_Detection_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os,sys,re
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

print ("CV2 Version - "+str(cv2.__version__))
# Out:
# CV2 Version - 4.1.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/'My Drive'/Images
# Out:
# 1.JPG  2.jpg  3.jpg  4.jpg  5.jpg  6.jpg  7.jpg

# %%
input_images = os.listdir("/content/drive/My Drive/Images/")

# %%
width=15
height=15
rows = 3
cols = 3
axes=[]
fig=plt.figure(figsize=(15,15))

for a in range(len(input_images)):
    input_img = "/content/drive/My Drive/Images/"+input_images[a]
    img = cv2.imread(input_img, cv2.IMREAD_COLOR)
    axes.append( fig.add_subplot(rows, cols, a+1) )
    subplot_title=("Subplot"+str(a))
    axes[-1].set_title(subplot_title)  
    plt.imshow(img)

fig.tight_layout()    
plt.show()

# %%
#from google.colab.patches import cv2_imshow
#face_cascade = cv2.CascadeClassifier('https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml')
width=15
height=15
rows = 3
cols = 3
axes=[]
fig=plt.figure(figsize=(15,15))
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

for a in range(len(input_images)):
    input = "/content/drive/My Drive/Images/"+input_images[a]
    img = cv2.imread(input, cv2.IMREAD_COLOR)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, minSize =(20, 20))
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
    axes.append( fig.add_subplot(rows, cols, a+1) )
    subplot_title=("Subplot"+str(a))
    axes[-1].set_title(subplot_title)  
    plt.imshow(img)
plt.show()
